# %% [markdown]
# # Lab 4. My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in sessions 1-6. You are expected to work on the assignments on your own between Tuesday the 8th at 11am and Wednesday the 9th at 11 am. We recomend hadning in an hour early to aviod any issues with traffic on the ELE.
#
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment.
#
# ## You can do this by creating [markdown cells](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm#:~:text=%20Jupyter%20Notebook%20-%20Markdown%20Cells%20%201,To%20attach%20link%20to%20text%2C%20place...%20More%20) in jupyter notebook, and writting in them.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### (1) Use pairplot to visualise the data. Colour code data points by the continent they are from.

# %%
#generate pairplot 

p_p= sns.pairplot(gapminder)
p_p.fig.suptitle("Pairplot",y=1.08)

# add colourcode data by continent
ppt = sns.pairplot(gapminder, hue = "continent")
ppt.fig.suptitle("Pairedplot with datapoints colourcoded by continent",y=1.08)
# Out:
# Text(0.5, 1.08, 'Pairedplot with datapoints colourcoded by continent')

# %% [markdown]
# ### (2) What patterns can you see? Are there any outliars?

# %% [markdown]
# 1.Africa has the highest datapoints in the dataset and oceania has the least datapoints in the dataset.
#
# 2.lifeExp increasing with time and so is gdppercap, and the higher the gdppercapita, better the lifeexpectancy, hence gdppercapta and lifeexp are positivly correlated.
#
# 3.Africa mostly had the least life expectancy in all of the given year but it relativlely improved with time.
#
# 4.Polpulation in Asian countries increased significantly with time.

# %% [markdown]
# Asia and Africa are outlier in most of the plots above. Mostly, Asia's datapoints differ significantly in the graph from the rest of the datapoints in the graph making it an outlier.For example lets consider lifeExp plot of contients over years, here Asia and Africa are condidered outliers.

# %%
#generating scatterplot to observer outliers

x = sns.scatterplot(x='lifeExp', y='year', data=gapminder, hue = "continent")
plt.legend(loc="upper center", bbox_to_anchor=(1.5, 1.15), ncol=2)

x.set_title('LifeExp of contients over the years');
x.set_xlabel('LifeExp');
x.set_ylabel('Year');

# %% [markdown]
# ### (3) Filter the dataset to find rows in which life GDP per capita is greater than 60,000

# %%
Filter1= gapminder[(gapminder['gdpPercap']>60000)]

# %%
Filter1
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %% [markdown]
# ### (4) What does this tell us about the data, as seen in the question (1)  pairplot?

# %% [markdown]
# Max gdpPercap value is 113523.1329. which is of Kuwait. The outliers in the below gdpPercap plot, Kuwait is mostly the Asian outlier ploted in the right of the graph.

# %%
x = sns.scatterplot(x='gdpPercap', y='year', data=gapminder, hue = "continent")
plt.legend(loc="upper center", bbox_to_anchor=(1.5, 1.15), ncol=2)

x.set_title('gdpPercap of contients over the years');
x.set_xlabel('gdpPercap');
x.set_ylabel('Year');

# %% [markdown]
# ### (5) Find the rows in the dataframe with the top 20 life expectancies

# %%
#calculate max lifeExp for reference

##gapminder[('lifeExp')].max()

top20_lifeExp = gapminder.sort_values(['lifeExp'], ascending=False).head(20)

# %%
top20_lifeExp
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
# 670   Hong Kong, China      Asia  2002   81.495    6762476  30209.01516
# 71           Australia   Oceania  2007   81.235   20434176  34435.36744
# 1427             Spain    Europe  2007   80.941   40448191  28821.06370
# 1475            Sweden    Europe  2007   80.884    9031088  33859.74835
# 767             Israel      Asia  2007   80.745    6426679  25523.27710
# 801              Japan      Asia  1997   80.690  125956499  28816.58499
# 539             France    Europe  2007   80.657   61083916  30470.01670
# ...

# %% [markdown]
# ### (6) Plot the evolution of life expectancy, population and GDP per capita of Kuwait

# %%
#Extract Kuwait data from the gapminder data set

kdata = gapminder[gapminder['country']=='Kuwait']

kdata
# Out:
#     country continent  year  lifeExp      pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565   160000  108382.35290
# 853  Kuwait      Asia  1957   58.033   212846  113523.13290
# 854  Kuwait      Asia  1962   60.470   358266   95458.11176
# 855  Kuwait      Asia  1967   64.624   575003   80894.88326
# 856  Kuwait      Asia  1972   67.712   841934  109347.86700
# 857  Kuwait      Asia  1977   69.343  1140357   59265.47714
# 858  Kuwait      Asia  1982   71.309  1497494   31354.03573
# 859  Kuwait      Asia  1987   74.174  1891487   28118.42998
# 860  Kuwait      Asia  1992   75.190  1418095   34932.91959
# 861  Kuwait      Asia  1997   76.156  1765345   40300.61996
# 862  Kuwait      Asia  2002   76.904  2111561   35110.10566
# 863  Kuwait      Asia  2007   77.588  2505559   47306.98978

# %%
#Extract data needed to plot the evolution of life expectancy, population and GDP per capita of Kuwait from the kuwait dataframe
graphdata = kdata[['country', 'lifeExp' , 'pop' , 'gdpPercap','year']]
graphdata
# Out:
#     country  lifeExp      pop     gdpPercap  year
# 852  Kuwait   55.565   160000  108382.35290  1952
# 853  Kuwait   58.033   212846  113523.13290  1957
# 854  Kuwait   60.470   358266   95458.11176  1962
# 855  Kuwait   64.624   575003   80894.88326  1967
# 856  Kuwait   67.712   841934  109347.86700  1972
# 857  Kuwait   69.343  1140357   59265.47714  1977
# 858  Kuwait   71.309  1497494   31354.03573  1982
# 859  Kuwait   74.174  1891487   28118.42998  1987
# 860  Kuwait   75.190  1418095   34932.91959  1992
# 861  Kuwait   76.156  1765345   40300.61996  1997
# 862  Kuwait   76.904  2111561   35110.10566  2002
# 863  Kuwait   77.588  2505559   47306.98978  2007

# %%
#Plot the evolution of life expectancy
graphdata.plot( 'year', 'lifeExp')
 
# naming the x axis
plt.xlabel('year')
# naming the y axis
plt.ylabel('LifeExp')
 
# giving a title to my graph
plt.title('LifeExp of Kuwait over years')
 
# function to show the plot
plt.show()

# %%
#Plot the evolution of pop

##gapminder[gapminder['country']=='Kuwait']['pop'].plot()


graphdata.plot( 'year', 'pop')
 
# naming the x axis
plt.xlabel('year')
# naming the y axis
plt.ylabel('population')
 
# giving a title to my graph
plt.title('populationof Kuwait over years')
 
# function to show the plot
plt.show()

# %%
#Plot the evolution of gdpPercap

##gapminder[gapminder['country']=='Kuwait']['gdpPercap'].plot()


graphdata.plot( 'year', 'gdpPercap')
 
# naming the x axis
plt.xlabel('year')
# naming the y axis
plt.ylabel('gdpPercap')
 
# giving a title to my graph
plt.title('gdpPercap of Kuwait over years')
 
# function to show the plot
plt.show()

# %%
#Plot the evolution of life expectancy, population and GDP per capita of Kuwait

graphdata.plot('year')

plt.title(' evolution of life expectancy, population and GDP per capita of Kuwait',y=1.08)
# Out:
# Text(0.5, 1.08, ' evolution of life expectancy, population and GDP per capita of Kuwait')

# %% [markdown]
# ### (7) Visualise the distribution of GDP per capita of countries and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# #### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# #### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
# plot of distribution of GDP per capita of countries and life expectancy across the dataframe

plott = sns.scatterplot(x='lifeExp', y='gdpPercap', data=gapminder, hue = "continent")
plt.legend(loc="upper center", bbox_to_anchor=(1.5, 1.15), ncol=2)

plott.set_title('gdpPercap Vs lifeExp');

# %%
#linear regression of gdpPercap and LifeExp
sns.lmplot(x='lifeExp', y='gdpPercap', data=gapminder)

# %% [markdown]
# ### (8) Visualise the distribution of year and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
#plot of distribution of year and life expectancy across the dataframe
plott2 = sns.scatterplot(x='year', y='lifeExp', data=gapminder, hue = "continent")
plt.legend(loc="upper center", bbox_to_anchor=(1.5, 1.15), ncol=2)

plott2.set_title('year Vs lifeExp');

# %%
#linear regression of year and LifeExp
sns.lmplot(x="year", y="lifeExp", data=gapminder);

# %% [markdown]
# ### (9) Use Boxplots or violinplots to visualise the distribution of change in life expectancy from 1952 to 2007.
#
# Hint tools from lab 6 may be helpful.

# %%
#Building dataframe of datapoint which lie between years 1952 to 2007
period= gapminder[(gapminder['year']>=1952) & (gapminder['year']<=2007)]
period
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
#creating changeinLifeExp column and loading data points 

period['changeinLifeExp']=period['lifeExp'].diff()
period['changeinLifeExp']
#period=period.drop(labels=0, axis=0)
#period['changeinLifeExp']

period
# Out:
#           country continent  year  lifeExp       pop   gdpPercap  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#       changeinLifeExp
# 0                 NaN
# 1               1.531
# 2               1.665
# 3               2.023
# 4               2.068
# ...               ...
# ...

# %%
bp1= period

# %%
#slicing the required data
bp_data= bp1.loc[:, ['year', 'changeinLifeExp']]
bp_data
# Out:
#       year  changeinLifeExp
# 0     1952              NaN
# 1     1957            1.531
# 2     1962            1.665
# 3     1967            2.023
# 4     1972            2.068
# ...    ...              ...
# 1699  1987            1.988
# 1700  1992           -1.974
# 1701  1997          -13.568
# 1702  2002           -6.820
# 1703  2007            3.498
#
# [1704 rows x 2 columns]

# %%
#dropping NaN 
bp1= bp_data.dropna()
bp1
# Out:
#       year  changeinLifeExp
# 1     1957            1.531
# 2     1962            1.665
# 3     1967            2.023
# 4     1972            2.068
# 5     1977            2.350
# ...    ...              ...
# 1699  1987            1.988
# 1700  1992           -1.974
# 1701  1997          -13.568
# 1702  2002           -6.820
# 1703  2007            3.498
#
# [1703 rows x 2 columns]

# %%
#Generating boxplot to visualise the distribution of change in life expectancy from 1952 to 2007.

bp = sns.boxplot(x='year', y='changeinLifeExp', data=bp1[bp1['year'] >1952])
bp.set_title('Change in LifeExp')

#bp.set_xlabel('year')
#bp.set_ylabel('changeinLifeExp')
# Out:
# Text(0.5, 1.0, 'Change in LifeExp')

# %% [markdown]
# ### (10) Continue this analysis of the data. Include code cells, their outputs and markdown cells where you write about your findings. What patterns can you observe in the data?

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
avgLE=gapminder.groupby(['continent', 'year'])['lifeExp'].mean()

# %%
avgLE
# Out:
# continent  year
# Africa     1952    39.135500
#            1957    41.266346
#            1962    43.319442
#            1967    45.334538
#            1972    47.450942
#            1977    49.580423
#            1982    51.592865
#            1987    53.344788
#            1992    53.629577
#            1997    53.598269
#            2002    53.325231
#            2007    54.806038
# Americas   1952    53.279840
#            1957    55.960280
#            1962    58.398760
#            1967    60.410920
#            1972    62.394920
#            1977    64.391560
#            1982    66.228840
#            1987    68.090720
#            1992    69.568360
#            1997    71.150480
#            2002    72.422040
#            2007    73.608120
# Asia       1952    46.314394
#            1957    49.318544
#            1962    51.563223
#            1967    54.663640
#            1972    57.319269
#            1977    59.610556
#            1982    62.617939
# ...

# %%
#Average lifeExp of continents over years
avgLE.unstack(level=0).plot(kind='line', subplots=False,figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Observations: The average life expectancies of all continents is increasing with time and Oceania has the best average growth where as africa has the least avg lifeExp increase.

# %%
India_data = gapminder[gapminder['country']=='India']

# %%
#India_data['lifeExp'].mean()
India_data
# Out:
#     country continent  year  lifeExp         pop    gdpPercap
# 696   India      Asia  1952   37.373   372000000   546.565749
# 697   India      Asia  1957   40.249   409000000   590.061996
# 698   India      Asia  1962   43.605   454000000   658.347151
# 699   India      Asia  1967   47.193   506000000   700.770611
# 700   India      Asia  1972   50.651   567000000   724.032527
# 701   India      Asia  1977   54.208   634000000   813.337323
# 702   India      Asia  1982   56.596   708000000   855.723538
# 703   India      Asia  1987   58.553   788000000   976.512676
# 704   India      Asia  1992   60.223   872000000  1164.406809
# 705   India      Asia  1997   61.765   959000000  1458.817442
# 706   India      Asia  2002   62.879  1034172547  1746.769454
# 707   India      Asia  2007   64.698  1110396331  2452.210407

# %%
#Pairplot with India's data
plot_I= sns.pairplot(India_data)

# %%
#linear regression plot with lifeExp and years

sns.lmplot(x="year", y="lifeExp", data=India_data);

# %% [markdown]
# observation:with time/years India's Life expentancy increased

# %%
#Extracting China's data

China_data = gapminder[gapminder['country']=='China']

# %%
China_data
# Out:
#     country continent  year   lifeExp         pop    gdpPercap
# 288   China      Asia  1952  44.00000   556263527   400.448611
# 289   China      Asia  1957  50.54896   637408000   575.987001
# 290   China      Asia  1962  44.50136   665770000   487.674018
# 291   China      Asia  1967  58.38112   754550000   612.705693
# 292   China      Asia  1972  63.11888   862030000   676.900092
# 293   China      Asia  1977  63.96736   943455000   741.237470
# 294   China      Asia  1982  65.52500  1000281000   962.421381
# 295   China      Asia  1987  67.27400  1084035000  1378.904018
# 296   China      Asia  1992  68.69000  1164970000  1655.784158
# 297   China      Asia  1997  70.42600  1230075000  2289.234136
# 298   China      Asia  2002  72.02800  1280400000  3119.280896
# 299   China      Asia  2007  72.96100  1318683096  4959.114854

# %%
#Concatenation of india's and china's data
IND_CHI = pd.concat([India_data, China_data], axis=0)

# %%
IND_CHI
# Out:
#     country continent  year   lifeExp         pop    gdpPercap
# 696   India      Asia  1952  37.37300   372000000   546.565749
# 697   India      Asia  1957  40.24900   409000000   590.061996
# 698   India      Asia  1962  43.60500   454000000   658.347151
# 699   India      Asia  1967  47.19300   506000000   700.770611
# 700   India      Asia  1972  50.65100   567000000   724.032527
# 701   India      Asia  1977  54.20800   634000000   813.337323
# 702   India      Asia  1982  56.59600   708000000   855.723538
# 703   India      Asia  1987  58.55300   788000000   976.512676
# 704   India      Asia  1992  60.22300   872000000  1164.406809
# 705   India      Asia  1997  61.76500   959000000  1458.817442
# 706   India      Asia  2002  62.87900  1034172547  1746.769454
# 707   India      Asia  2007  64.69800  1110396331  2452.210407
# 288   China      Asia  1952  44.00000   556263527   400.448611
# 289   China      Asia  1957  50.54896   637408000   575.987001
# ...

# %%
#comparing linearregresions of life exp in both the countries
sns.lmplot(x="year", y="lifeExp", data=IND_CHI, hue='country');

# %%
#Extracting Egypt's data



Egypt_data = gapminder[gapminder['country']=='Egypt']

# %%
Egypt_data['lifeExp'].mean()

Egypt_data
# Out:
# 56.243

# %%
#creating dataframe with 3 nations data
ICE_data=pd.concat([IND_CHI,Egypt_data], axis=0)

# %%
ICE_data
# Out:
#     country continent  year   lifeExp         pop    gdpPercap
# 696   India      Asia  1952  37.37300   372000000   546.565749
# 697   India      Asia  1957  40.24900   409000000   590.061996
# 698   India      Asia  1962  43.60500   454000000   658.347151
# 699   India      Asia  1967  47.19300   506000000   700.770611
# 700   India      Asia  1972  50.65100   567000000   724.032527
# 701   India      Asia  1977  54.20800   634000000   813.337323
# 702   India      Asia  1982  56.59600   708000000   855.723538
# 703   India      Asia  1987  58.55300   788000000   976.512676
# 704   India      Asia  1992  60.22300   872000000  1164.406809
# 705   India      Asia  1997  61.76500   959000000  1458.817442
# 706   India      Asia  2002  62.87900  1034172547  1746.769454
# 707   India      Asia  2007  64.69800  1110396331  2452.210407
# 288   China      Asia  1952  44.00000   556263527   400.448611
# 289   China      Asia  1957  50.54896   637408000   575.987001
# ...

# %%
sns.lmplot(x="year", y="lifeExp", data=ICE_data, hue='country');

# %% [markdown]
# lifeExp is better in China comparatively.India and Egypt has close but not same mean values of lifeExp

# %%
sns.scatterplot(x='year', y='pop', data=ICE_data, hue = "country")
# Out:
# <AxesSubplot:xlabel='year', ylabel='pop'>

# %% [markdown]
# China followeded by India show a linear increase in population with year but Egypt's population held almost constant over years.
