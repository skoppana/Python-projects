# %% [markdown]
# ## BEMM458 Final assessment

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# You have been hired to work with a team of executives for a company that make plastics and sell them to a number of clients. These executives are worried that public perception of plastic waste may cause the companies buying bottles and other plastic products from them to go to another manufacturer.
#
# In this coursework you will be given a twitter dataset in which plastic waste as well as waste from these client companies is being tweeted about. You will be analysing it to understand the public perception of these companies and plastic waste more generally.
#
# Because you are working with a team of executives you need to balance two competing demands, (1) you need to be able to justify everything you say in case you are questioned on it and (2) you need to be able to justify everything you say just in case they question you on it.
#
# Because you are working at an executive level the questions have been deliberately made very open ended, to give you space to take the initiative. As you are in the early part of your journey as business analysts, some suggestions have been made for most of the questions – but you do not have to follow them, and I will mark creative or original thinking well.
#
# Because you are working at an executive level, and executives do not have much time you need to be brief. I’ve left a markdown cell at the top of every question where in less than 100 words you are to summarize your key findings from the questions.
# In the cells below that, put all your code, as well as explanations of what your code is doing and why you are choosing to put one piece of information rather than another in the 100-word summary.
#
# In some cases, you will be asked why you made certain choices in previous questions.  In that case, just right a brief 100 word summary of your reasons.
# Don’t stress about summarizing your work too much – using summaries will help you to get good marks on big open-ended questions because they make sure that the marker sees what you think is important.
#
# Some of these questions are genuinely hard, but they are all being marked with equal weighting. If you find yourself stuck read through your class notes or watch class videos and online tutorials. You will be able to do everything that's being asked of you if you put the time in.

# %%
#set everything up
#import pandas as pd
#import seaborn as sns

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

pd.options.display.max_colwidth = 400
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df.to_csv(r'/Users/Apple/Downloads/coco.csv', index = False)

# %%
#read in the data 
ConversationsLean=pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458_OLD/master/data/ConversationsLean.csv')
#ConversationsLean.info()

# %%
df

# %%
ConversationsLean.head(3)
# Out:
#    Unnamed: 0            tweet.created_at      tweet.id  \
# 0           0  2019-03-05 00:55:05.000000  1.102734e+18
# 1           1  2018-10-04 17:01:10.000000  1.047894e+18
# 2           2  2018-10-04 14:33:54.000000  1.047857e+18
#
#                                                                                                                                                                                                                                                      tweet.full_text  \
# 0                    The Recycling Myth. “I hear the excuse all the time, ‘I use single-use plastic, but I recycle it, so it’s OK.’ Unfortunately, that is not the truth.” #plasticpollutes #recyclingisnottheanswer https://t.co/yD75iVbd6k https://t.co/ocQbPhjqLN
# ...

# %%
ConversationsLean.groupby('stakeholder').count()
# Out:
#                   Unnamed: 0  tweet.created_at  tweet.id  tweet.full_text  \
# stakeholder
# Artist                   104               104       104              104
# Multinational             20                20        20               20
# NGO                      241               241       241              241
# OtherInstitution          51                51        51               51
# Scientific                24                24        24               24
#
#                   tweet.entities  tweet.user.id  tweet.user.screen_name  \
# stakeholder
# Artist                       104            104                     104
# Multinational                 20             20                      20
# NGO                          241            241                     241
# OtherInstitution              51             51                      51
# Scientific                    24             24                      24
#
# ...

# %%
 df= ConversationsLean

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet_full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
# ...

# %% [markdown]
# The dataset you have been given contains 30 columns:
# * Columns 0-17 of the data includes data from twitter.
# * Columns 18-29 are based on a NLP processing of the tweets, which attempts to gauge the tweets emotion.
# * Column 30 tells us what kind of account the tweet comes from.

# %% [markdown]
# #### Task 1. Look for relationships in the numerical columns that have tweet in the title.  Based on your understanding of the data relationships and intuitions about twitter try to define a numerical measure of impact.
# - Try visualizing plots of the distribution of the values in numerical columns, and plotting the relationships between the values of pairs of collumns.
# - Which numerical columns correlate with each other?
# - What kind of correlations do they have?
# - If two features are strongly correlated they might not both be necessary in your measure of impact.
# - A measure of impact may be as simple as the number of times a tweet has been liked or retweeted or it may be as complex as a function that takes the inputs of those columns and outputs a scalar or a vector.

# %% [markdown]
# summary:
#
# distribution of the values in numerical columns
# - The dataset consits of tweets from 28 users accounts over time regarding Plastic. 'PlasticPollutes' account has a the maxium number of tweets in the dataset, ie close to 130 tweets.Hence making its the most active user in the dataset. its followed by PlasticfreeBeth which is has almost half as many as PlasticPollutes.
#
# #CORRELATION
# -  tweet.user.favourites_count is strongly correlated to user's followers and friends count, which make sense because the more number of followers and friends a user has the higher are the chances to get a tweet liked.
#
# - there is a correlation between the user's followers count and the user's status count. SO either the user who has more friends is active on twitter or the user has more friends because they actively seek friends.
#
# - most favourited tweets are also most likely to be retweeted.

# %%
#filtering colums with tweet in column name
df1 = df.filter(['tweet.user.followers_count','tweet.user.friends_count','tweet.user.favourites_count','tweet.user.statuses_count',
                 'tweet.retweet_count','tweet.favorite_count'], axis=1)
#df_2 = df.filter(['tweet.id','tweet.user.id','tweet.user.followers_count','tweet.user.friends_count','tweet.user.favourites_count','tweet.user.statuses_count','tweet.retweet_count','tweet.favorite_count'], axis=1)

# %%
df1.head()
# Out:
#    tweet.user.followers_count  tweet.user.friends_count  \
# 0                       45953                      6595
# 1                       45953                      6595
# 2                       45953                      6595
# 3                       45953                      6595
# 4                       24165                      4022
#
#    tweet.user.favourites_count  tweet.user.statuses_count  \
# 0                        13453                      18732
# 1                        13453                      18732
# 2                        13453                      18732
# 3                        13453                      18732
# 4                         2025                       6190
#
#    tweet.retweet_count  tweet.favorite_count
# 0                 47.0                  66.0
# 1                 15.0                  21.0
# 2                 27.0                  35.0
# 3                 45.0                  56.0
# 4                  5.0                  10.0

# %%
ax = df.groupby('tweet.user.screen_name').count().plot(kind='bar', title='Distribution of data',legend=False)
# Storing data in lists.
#text, sentiment = list(df['tweet.user.followers_count']), list(df['tweet.user.screen_name'])

# %%
p = df_2.hist(figsize = (20,20))

# %%
p_p= sns.pairplot(df1)

# %%
df1.corr()
# Out:
#                              tweet.user.followers_count  \
# tweet.user.followers_count                     1.000000
# tweet.user.friends_count                       0.048089
# tweet.user.favourites_count                    0.144238
# tweet.user.statuses_count                      0.856409
# tweet.retweet_count                            0.461871
# tweet.favorite_count                           0.694925
#
#                              tweet.user.friends_count  \
# tweet.user.followers_count                   0.048089
# tweet.user.friends_count                     1.000000
# tweet.user.favourites_count                  0.715652
# tweet.user.statuses_count                    0.368812
# tweet.retweet_count                          0.080071
# tweet.favorite_count                         0.085703
#
#                              tweet.user.favourites_count  \
# tweet.user.followers_count                      0.144238
# tweet.user.friends_count                        0.715652
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer 

import matplotlib.colors

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#221f1f', '#b20710','#f5f5f1'])

corr = df1.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
    )
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
    );

# %% [markdown]
# #### Task 2. Explore the impact of different individuals and groups
# 	- what groups of stakeholders in the datasets have more impact
# 	-which users in the datasets have more impact

# %% [markdown]
# summary:
# I chose to measure impact by the retweet count and favourited count, because higher retweeted and favourited tweet means that it reaches many more audience.
#
# NGO's have the highest impact because they have the highest retweet count aswell as favorite count.

# %%
df.groupby(['stakeholder'])[['tweet.retweet_count','tweet.favorite_count']].max()
# Out:
#                   tweet.retweet_count  tweet.favorite_count
# stakeholder
# Artist                           20.0                  71.0
# Multinational                   118.0                 345.0
# NGO                            1074.0                1236.0
# OtherInstitution                 65.0                  71.0
# Scientific                      302.0                   7.0

# %% [markdown]
# - To find the most impactful user we take the average of 'tweet.retweet_count','tweet.favorite_count' across all the usernames.
# - The average is taken because tweets are not evenly distributed across all the individual users.As deduced before NGO's are the most impactful.
# - the user GREENPEACE is the most impactful of all the users in the data set with it tweets being faviourited on an average of 289 times and its post being retweeted on an average of 180 times. This is intutively right given Green peace is a global environment campaigner across the world

# %%
df.groupby('tweet.user.screen_name').size()
# Out:
# tweet.user.screen_name
# 5gyres              59
# AdvScientists        2
# Algalita            14
# AnnaTurns            1
# DRussoInnovate      27
# EndPlasticWaste      5
# EnvirHealthNews      3
# FlotsamWeaving       1
# GordonJMillar        1
# Greenpeace          22
# HealTheBay           4
# Maqueda              4
# MaxLiboiron          4
# Nestle              12
# NoPlasticStraws     20
# NonToxicRev          4
# PepsiCo              4
# PlasticOceansUS      3
# PlasticPollutes    127
# PlasticfreeBeth     69
# SongsofJBrowne       1
# Unilever             4
# WRAP_UK             46
# bahaplasmvmnt        1
# captainplanetfd      4
# celinecousteau       1
# driftersproject      2
# janettewallis        2
# dtype: int64

# %%
#most impactful user
mostimp_users = df.groupby(['tweet.user.screen_name'])[['tweet.retweet_count','tweet.favorite_count']].mean().sort_values(by=['tweet.retweet_count'],ascending=False).reset_index()
mostimp_users
# Out:
#    tweet.user.screen_name  tweet.retweet_count  tweet.favorite_count
# 0              Greenpeace           179.136364            288.954545
# 1                Algalita            38.571429              1.214286
# 2         PlasticPollutes            33.401575             31.708661
# 3                Unilever            27.750000             53.750000
# 4           janettewallis            26.500000              0.000000
# 5         NoPlasticStraws            22.650000              5.850000
# 6           AdvScientists            21.500000              3.500000
# 7                  Nestle            19.000000             57.333333
# 8          SongsofJBrowne            17.000000              6.000000
# 9              HealTheBay            16.500000             12.500000
# 10         celinecousteau            15.000000             36.000000
# 11            MaxLiboiron            14.000000              1.750000
# 12         FlotsamWeaving            13.000000             23.000000
# ...

# %%
a=mostimp_users.head(10)

# %% [markdown]
# #### Task 3. Why did you choose your definition of impact for users/groups of users?

# %% [markdown]
# summary:
#
# I chose to measure impact by the retweet count and favourited count, because higher retweeted and favourited tweet means that it reaches many more audience and not all tweets that are favourited are retweeted and not all retweeted tweets are favourited. so i chose both the measures to estimate impact

# %%
#df.groupby(['tweet.user.screen_name'])['tweet.user.followers_count'].sort_values(by=['tweet.user.followers_count'],ascending=False).reset_index()

df.sort_values(by='tweet.user.followers_count', inplace=True, ascending=False)
a = df.head(200)

# %%
x = sns.scatterplot(x='tweet.retweet_count', y='tweet.favorite_count', data=a, hue = "tweet.user.screen_name")
plt.legend(loc="upper center", bbox_to_anchor=(1.5, 1.15), ncol=2)

x.set_title('impact of tweets');
x.set_xlabel('retweet');
x.set_ylabel('fav');

# %%
df
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 0             0  2019-03-05 00:55:05.000000  1.102734e+18
# 1             1  2018-10-04 17:01:10.000000  1.047894e+18
# 2             2  2018-10-04 14:33:54.000000  1.047857e+18
# 3             3  2018-08-16 21:20:06.000000  1.030203e+18
# 4             4  2018-03-28 21:35:09.000000  9.791097e+17
# ..          ...                         ...           ...
# 442          16  2015-07-06 15:04:55.000000  6.180731e+17
# 443          17  2017-10-05 19:53:16.000000  9.160285e+17
# 444          18  2019-06-09 14:27:28.000000  1.137728e+18
# 445          19  2019-01-08 11:09:45.000000  1.082595e+18
# 446          20  2018-06-06 07:15:36.000000  1.004261e+18
#
# ...

# %% [markdown]
# #### Task 4. Which hashtags have the most impact?
# 	- A way of assessing this would be to calculate the impact for each tweet, and then calculate the total impact.

# %% [markdown]
# I extract hastags(#) and user tags(@) from original database by spliting tweet_full_text into individual words and then extracting entities starting with # and @ and assigning them to a new column.
#
# Most impactful hashtags are calculated by first taking average of retweet & favorites in the entire dataset and then filtering out every tweets that are above these average measures.
# then we count the number of time a hastag appers in the list of tweets above the average mark.
#
# We found that the top most used Hashtag is #BreakFreeFromPlastic which was hastaged 12 time in the dataset of tweets with retweets and faviourites more than average.
# hence #BreakFreeFromPlastic is the most impactful hashtag.

# %%
df. rename(columns = {'tweet.full_text':'tweet_full_text'}, inplace = True)

# %%
df2= ConversationsLean
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet_full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
# ...

# %% [markdown]
# summary:

# %%
tags_data = pd.DataFrame(columns=['hash_tags','user_tags'])
def tag_finder(text):
    hash_tags = []
    tags = []
    for i in text.split():
        if i.startswith('#'):
            hash_tags.append(i)
        if i.startswith('@'):
            tags.append(i)
    return hash_tags, tags
tags_data['hash_tags'],tags_data['user_tags'] = zip(*df2['tweet_full_text'].apply(tag_finder))
tags_data
# Out:
#                                                          hash_tags  \
# 0                     [#plasticpollutes, #recyclingisnottheanswer]
# 1    [#recycling, #plasticpollution., #plastics, #plasticpollutes]
# 2    [#recycling, #plasticpollution., #plastics, #plasticpollutes]
# 3                                             [#reuse, #recycling]
# 4                   [#recyclingisnotenough, #breakfreefromplastic]
# ..                                                             ...
# 442                                                  [#DidYouKnow]
# 443                                [#DidYouKnow, #RefuseSingleUse]
# 444    [#DidYouKnow, #WorldOceansDay?, #NestléCares, #WeAreNestlé]
# 445                                                  [#DidYouKnow]
# 446                           [#DidYouKnow, #BeatPlasticPollution]
#
#                user_tags
# 0                     []
# 1                     []
# 2                     []
# 3                     []
# 4                     []
# ...

# %%
#df = pd.merge(df,tags_data,left_index=True, right_index=True)
df
#df= df.drop(columns=['user_tags_y'])
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 0             0  2019-03-05 00:55:05.000000  1.102734e+18
# 1             1  2018-10-04 17:01:10.000000  1.047894e+18
# 2             2  2018-10-04 14:33:54.000000  1.047857e+18
# 3             3  2018-08-16 21:20:06.000000  1.030203e+18
# 4             4  2018-03-28 21:35:09.000000  9.791097e+17
# ..          ...                         ...           ...
# 442          16  2015-07-06 15:04:55.000000  6.180731e+17
# 443          17  2017-10-05 19:53:16.000000  9.160285e+17
# 444          18  2019-06-09 14:27:28.000000  1.137728e+18
# 445          19  2019-01-08 11:09:45.000000  1.082595e+18
# 446          20  2018-06-06 07:15:36.000000  1.004261e+18
#
# ...

# %%
#calculating the average of followers, retweet and Fav's score.
avg_foll = df['tweet.user.followers_count'].mean()
avg_retweet = df['tweet.retweet_count'].mean()
avg_favorite = df['tweet.favorite_count'].mean()
print(f'avg followers : {avg_foll}   avg retweet : {avg_retweet}   avg favorite : {avg_favorite}')
# Out:
# avg followers : 126609.4071588367   avg retweet : 25.17897091722595   avg favorite : 29.29753914988814

# %%
#selecting tweets which have values above average to find the most impactful.
above_avg_tweets= df[(df['tweet.user.followers_count'] > 126609.4071588367)&(df['tweet.retweet_count'] > 25.17897091722595)&(df['tweet.favorite_count'] > 29.29753914988814)]

above_avg_tweets
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 105          59  2019-12-24 19:01:06.000000  1.209550e+18
# 106          60  2019-12-09 22:25:03.000000  1.204165e+18
# 107          61  2019-12-07 22:25:07.000000  1.203440e+18
# 108          62  2019-11-26 12:01:09.000000  1.199297e+18
# 109          63  2019-11-25 14:10:06.000000  1.198967e+18
# 111          65  2019-11-09 16:10:04.000000  1.193199e+18
# 112          66  2019-11-07 15:01:16.000000  1.192457e+18
# 113          67  2019-10-25 01:15:03.000000  1.187538e+18
# 114          68  2019-10-23 14:20:00.000000  1.187011e+18
# 115          69  2019-10-05 20:44:04.000000  1.180584e+18
# 116          70  2019-10-04 17:05:10.000000  1.180167e+18
# 117          71  2019-09-08 09:00:26.000000  1.170623e+18
# 118          72  2019-09-04 22:10:03.000000  1.169372e+18
# 119          73  2019-09-03 08:01:26.000000  1.168796e+18
# 120          74  2019-08-27 12:00:42.000000  1.166320e+18
# ...

# %%
 import nltk

# %%
#now from these filtered tweets lets extract and check which Hashtags appear the most
all_hash_tags = []
for i in above_avg_tweets['hash_tags']:
    if len(i)>0:
        for ele in i:
            all_hash_tags.append(ele)
tag_count_df1 = pd.DataFrame(all_hash_tags,columns=['HASHTAG']) # create a new dataframe for our hashtags
tag_count_df1 = tag_count_df.drop_duplicates()
tag_count_df1['count'] = tag_count_df1['HASHTAG'].apply(lambda x : all_hash_tags.count(x)) #function returns no of count per hashtag
tag_count_df1
# Out:
#                    HASHTAG  count
# 0    #BreakFreeFromPlastic     12
# 1   #BreakFreeFromPlastic.      1
# 2         #ReuseRevolution      2
# 3   #BreakFreeFromPlastic!      2
# 5   #BreakFreeFromPlastic…      1
# 10         #BrandAudit2019      1
# 13  #breakfreefromplastics      1
# 20  #breakfreefromplastic:      1
# 21   #breakfreefromplastic      1
# 22   #BeatPlasticPollution      1
# 23         #sustainability      1
# 24                 #Nestle      1
# 25        #circulareconomy      3
# 26                  #SDG12      2
# 28              #reusable,      1
# 29             #recyclable      1
# 30            #compostable      1

# %% [markdown]
# #### Task 5. Explore the NLP emotional analysis
#     -How are the scores for different emotions distributed in the dataset?
#     -Are some emotions correlated positively or negatively with each other?

# %% [markdown]
# summary:
# Anger and fear correlate highly with sadness.
# Joyand and trust and love are highly correalate
# sever toxicity correlates highly with threat whearas toxicity corilates with insult and identity hate.
# emotions such as obscene and love are negatively correlated.
# if we were to clasify the positively and and negatively correlated  emotions we see two broader types of emotions which can be classified as positive emotions and negative emotions.

# %%
df_3 = df.filter(['anger','fear','joy','love','sadness','trust','identity_hate','insult','obscene','severe_toxic','threat','toxic'], axis=1)

# %%
p_em = df_3.hist(figsize = (20,20))

# %%
df_3.corr()
# Out:
#                   anger      fear       joy      love   sadness     trust  \
# anger          1.000000  0.448224 -0.772268 -0.498920  0.645284 -0.452487
# fear           0.448224  1.000000 -0.695705 -0.427957  0.740662 -0.225597
# joy           -0.772268 -0.695705  1.000000  0.780607 -0.815044  0.675617
# love          -0.498920 -0.427957  0.780607  1.000000 -0.534648  0.702993
# sadness        0.645284  0.740662 -0.815044 -0.534648  1.000000 -0.488178
# trust         -0.452487 -0.225597  0.675617  0.702993 -0.488178  1.000000
# identity_hate  0.136401 -0.004650 -0.079642 -0.052514  0.035921 -0.084680
# insult         0.174893 -0.004273 -0.103039 -0.063664  0.051982 -0.110700
# obscene        0.174019 -0.007169 -0.100109 -0.058743  0.052097 -0.110123
# severe_toxic  -0.040334 -0.076635  0.052377  0.018273 -0.080624  0.014698
# threat         0.004069 -0.059549  0.027748  0.008800 -0.060803  0.012276
# toxic          0.295803  0.044853 -0.178969 -0.099040  0.136785 -0.173225
#
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer 

import matplotlib.colors

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['#221f1f', '#b20710','#f5f5f1'])

corr = df_3.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
    )
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
    );

# %%
#df_3.info()
sns.pairplot(df_3)

# %% [markdown]
# #### Task 6.	Explore relationship between NLP emotional analysis and impact.
# 		-do tweets with any certain emotion have more impact?

# %% [markdown]
# summary:
# I grouped love , trust and joy as positive emotion and the remainng as negative emotions.
#
# If we observe across a the given dataset we can notice Joy is promient but is closely followed by anger
#
# across the most imactfull user dataset we can observe anger is mostly surpassing the joy as well as other emotional catgories.
# so anger has the most impact 90 % of the times and is only rarely surpassed by joy

# %%
df_3.count()
# Out:
# anger            447
# fear             447
# joy              447
# love             447
# sadness          447
# trust            447
# identity_hate    447
# insult           447
# obscene          447
# severe_toxic     447
# threat           447
# toxic            447
# dtype: int64

# %%
positive = ConversationsLean[['love','joy','trust']].sum(axis=1)
positive
negative = ConversationsLean[['anger','fear','sadness','identity_hate','insult','obscene','threat','severe_toxic','toxic']].sum(axis=1)
negative

p=pd.DataFrame(positive,columns=['positive_score'])
n=pd.DataFrame(negative,columns=['negative_score'])

temp = pd.merge(p, n, left_index=True, right_index=True)
#score_table = pd.merge(temp, c, left_index=True, right_index=True) #create a datframe called 'score_table' used to hold all numerical measures of impact
#score_table
temp
# Out:
#      positive_score  negative_score
# 0          0.113830        0.927955
# 1          0.079444        1.522401
# 2          0.079444        1.522401
# 3          0.100613        1.044985
# 4          0.480962        0.510673
# ..              ...             ...
# 442        0.361713        0.546442
# 443        0.151134        1.237405
# 444        0.509443        0.690486
# 445        0.108340        1.167334
# 446        0.864880        0.250262
#
# [447 rows x 2 columns]

# %%
df = pd.merge(df,temp,left_index=True, right_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet_full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
# ...

# %%
df.plot(x="tweet.user.screen_name", y=['love','joy','trust','anger','fear','sadness','identity_hate','insult','obscene','threat','severe_toxic','toxic'], kind="line",figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='tweet.user.screen_name'>

# %%
above_avg_tweets.plot(x="tweet.user.screen_name", y=['love','joy','trust','anger','fear','sadness','identity_hate','insult','obscene','threat','severe_toxic','toxic'], kind="line",figsize=(18,6))
# Out:
# <AxesSubplot:xlabel='tweet.user.screen_name'>

# %% [markdown]
# #### Task 7. Which companies are mentioned the most?
# 		-write a program that looks through hashtags and user mentions and counts occurrences.

# %% [markdown]
# summary:
# users @PlasticPollutes and @circulareconomy are mentioned 12 times each and are bothe the most mentioned users.
# The Company that is most Mentioned is @amazon with count-8, followed by @Nestle-6, @Unilever-5, @PepsiCo-4 and @CocaCola-4
#
# Amazon is the most mentioned company  with a total of 9 mentions

# %%
all_user_tags = []
for i in df['user_tags_x']:
    if len(i)>0:
        for ele in i:
            all_user_tags.append(ele)
user_tag_count_df = pd.DataFrame(all_user_tags,columns=['User_Mention']) # create a new dataframe for our mentions
user_tag_count_df = user_tag_count_df.drop_duplicates()
user_tag_count_df['count'] = user_tag_count_df['User_Mention'].apply(lambda x : all_user_tags.count(x)) #function returns no of mentions
most_mentioned_users = user_tag_count_df.sort_values('count',ascending=False)#count of all mentions
most_mentioned_users.head(100)
# Out:
#           User_Mention  count
# 10   @PlasticPollutes:     12
# 220   @circulareconomy     12
# 34     @brkfreeplastic     11
# 147   @plasticfreebeth     11
# 167   @PlasticPollutes     11
# ..                 ...    ...
# 161   @LindsayOHealth:      1
# 163         @marc_2127      1
# 164      @ecokarenlee:      1
# 165  @YourOrganicLife:      1
# 396     @GGGInitiative      1
#
# [239 rows x 2 columns]

# %%
most_mentioned_users
# Out:
#           User_Mention  count
# 10   @PlasticPollutes:     12
# 220   @circulareconomy     12
# 34     @brkfreeplastic     11
# 147   @plasticfreebeth     11
# 167   @PlasticPollutes     11
# ..                 ...    ...
# 350        @donbribon:      1
# 352          @gfriend:      1
# 355          @setjeff:      1
# 361            @Amazi,      1
# 362     @in_gredients.      1
#
# [100 rows x 2 columns]

# %%
company_list = ['@amazon','@CocaCola','@PepsiCo','@Nestle','@Unilever']
mostmencomp = []
for i in company_list: #this loop is to find similar mentions by checking if most of its string characters match exactly the same (Advanced similarity checking can be done only using external libraries)
    for x in most_mentioned_users['User_Mention']:
        i_length = int(len(i))
        if x[:int(i_length/1.2)] == i[:int(i_length/1.2)]:
#             print(x," ",i,"\n")
            no =int(most_mentioned_users[most_mentioned_users['User_Mention']==x]['count'])
#             print(no,"\n------------------------------------------------------------------")
            mostmencomp.append((x,i,no))

# %%
mostmencomp
# Out:
# [('@amazon', '@amazon', 8),
#  ('@amazon’s', '@amazon', 1),
#  ('@CocaCola', '@CocaCola', 4),
#  ('@CocaCola,', '@CocaCola', 3),
#  ("@CocaCola's", '@CocaCola', 1),
#  ('@PepsiCo', '@PepsiCo', 4),
#  ('@Pepsi', '@PepsiCo', 2),
#  ('@PepsiCo,', '@PepsiCo', 2),
#  ('@Nestle', '@Nestle', 6),
#  ('@Nestle,', '@Nestle', 4),
#  ('@Unilever', '@Unilever', 5)]

# %% [markdown]
# #### Task 8. Pick a company, find the emotional scores of tweets mentioning them. How do the emotions in tweets mentioning them compare to the emotions of the tweets in general?

# %% [markdown]
# summary: I picked unilever and we can see that anger outweights all other emotion catogories and most of these comments are made by PlasticPollutes and unilever also attracted a negative comment from Greenpeace as well.
# The negative comments outweigh the positive comments by huge margines.

# %%
def find(x):
    if (("@Unilever")or("Unilever'")) in x:
        return "Found"
f = df['user_tags_x'].apply(find)
f = f[f == 'Found']
f.index #these are index location of tweets where @amazon are mentioned
amazon_tweets = df.loc[f.index] #df filtering using the above index
amazon_tweets.plot(x="tweet.user.screen_name", y=['love','joy','trust','anger','fear','sadness','identity_hate','insult','obscene','threat','severe_toxic','toxic'], kind="line",figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='tweet.user.screen_name'>

# %%
def find(x):
    if (("@Unilever")or("Unilever'")) in x:
        return "Found"
f = df['user_tags_x'].apply(find)
f = f[f == 'Found']
f.index #these are index location of tweets where @amazon are mentioned
amazon_tweets = df.loc[f.index] #df filtering using the above index
amazon_tweets.plot(x="tweet.user.screen_name", y=["positive_score", "negative_score"], kind="bar",figsize=(16,6))
# Out:
# <AxesSubplot:xlabel='tweet.user.screen_name'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet_full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
# ...

# %% [markdown]
# #### Task 9. Repeat task 8 for all companies mentioned in the dataset.
#     -try using the code you wrote for task 8 and looping it over a list from the companies in question 7

# %% [markdown]
# summary:
# for almost almost for all of the companies the negative scores outweigh the positive score by a noticable margine

# %%
df.groupby(['stakeholder']).size()
# Out:
# stakeholder
# Artist              104
# Multinational        20
# NGO                 241
# OtherInstitution     51
# Scientific           24
# dtype: int64

# %%
comp_df = df[df['stakeholder']=='Multinational']

# %%
comp_df['tweet.user.screen_name']
# Out:
# 42       Nestle
# 43       Nestle
# 44      PepsiCo
# 45      PepsiCo
# 333      Nestle
# 334      Nestle
# 335      Nestle
# 336      Nestle
# 337      Nestle
# 338      Nestle
# 339      Nestle
# 340     PepsiCo
# 341     PepsiCo
# 342    Unilever
# 343    Unilever
# 344    Unilever
# 345    Unilever
# 444      Nestle
# 445      Nestle
# 446      Nestle
# Name: tweet.user.screen_name, dtype: object

# %%
x = sns.scatterplot(x='positive_score', y='negative_score', data=comp_df, hue = "tweet.user.screen_name")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 447 entries, 0 to 446
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   447 non-null    int64
#  1   tweet.created_at             447 non-null    object
#  2   tweet.id                     447 non-null    float64
#  3   tweet_full_text              447 non-null    object
#  4   tweet.entities               447 non-null    object
#  5   tweet.user.id                447 non-null    int64
#  6   tweet.user.screen_name       447 non-null    object
#  7   tweet.user.followers_count   447 non-null    int64
#  8   tweet.user.friends_count     447 non-null    int64
#  9   tweet.user.favourites_count  447 non-null    int64
#  10  tweet.user.statuses_count    447 non-null    int64
#  11  tweet.retweet_count          447 non-null    float64
#  12  tweet.favorite_count         447 non-null    float64
# ...

# %%
def pick_emotion(x):
    for i in df['tweet_full_text']:
        if x in i:
            a = df.loc[df[df['tweet_full_text']==i].index][["positive_score", "negative_score"]]
#           print(x,'\n',str(a['positive_score']).split()[1],'\n',str(a['negative_score']).split()[1],'\n',str(a['really_negative_score']).split()[1],'\n ... \n')
            return (x,i,str(a['positive_score']).split()[1],str(a['negative_score']).split()[1])
    #print("\n----------------------------------------------------------------------------------------------------------------------------------------------------------------------")
new_series = most_mentioned_users['User_Mention'].apply(pick_emotion)
mention_emotions = pd.DataFrame([[a, b, c, d,] for a,b,c,d in new_series.values], columns=("Mention Tweet Positive_score Negative_score ").split()) #the dataframe containing all mentions per tweet and their emotions
mean_emotion_per_mention = mention_emotions.groupby('Mention',as_index=False).mean() #avg score of emotions per mention is calculated 
mean_emotion_per_mention
# Out:
# /Users/Apple/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              Mention  Positive_score  Negative_score
# 0       @500Startups        0.117848        1.134556
# 1    @7iffanynorton:        0.232734        0.756785
# 2            @Amazi,        1.389076        0.122127
# 3           @Ampacet        0.794708        0.277160
# 4           @AquaTru        1.512225        0.169868
# ..               ...             ...             ...
# 234     @swellbottle        1.608596        0.161945
# 235   @toxicfreebaby        0.259478        0.932001
# 236       @travelTTC        1.213317        0.163614
# 237       @voxdotcom        0.084298        1.330191
# ...

# %%
p3 = sns.scatterplot(x='Positive_score', y='Negative_score', data=mean_emotion_per_mention, hue = "Mention", legend=None )

# %% [markdown]
# #### Task 10.	Pick a company that are being negatively mentioned in tweets. Write out a plan for how you would retain them as a client for the company you are working with.

# %% [markdown]
# summary:
# I chose PepsiCo because it recieved many negative comments mostly from User Plastic pollutes and one each from Greenpeace and 5gyres, makiking it the most negatively reviewed company. All the tweets mention have PepsiCo is overusing plastic. These are high impact tweets and they could cause damage to the company.
#
# I would suggest a noticeable  switch over to non plastic by the PepsiCo company. Because on observation the top 10 tweets with highest positive score are tweets commending either stoping use of plastic or supporting the motion.
#
# So, public in general is more intrested in companies using eco friendly packaging and sustainable manufacturing.

# %%
index_list=[]
for i in df['tweet_full_text']:
    if ("@Pepsi"or"@PepsiCo"or"@PepsiCo,") in i:
        index_list.append(df[df['tweet_full_text']==i].index[0])
pd.Series(index_list)
df.loc[index_list]
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 57           11  2019-11-18 20:25:05.000000  1.196525e+18
# 63           17  2019-10-23 18:35:04.000000  1.187075e+18
# 64           18  2019-10-23 12:02:26.000000  1.186976e+18
# 87           41  2018-11-01 14:20:09.000000  1.058001e+18
# 89           43  2018-10-16 21:39:39.000000  1.052313e+18
# 91           45  2018-10-09 20:45:21.000000  1.049763e+18
# 114          68  2019-10-23 14:20:00.000000  1.187011e+18
# 131          85  2019-07-09 20:22:40.000000  1.148689e+18
#
#                                                                                                                                                                                                                                                                                  tweet_full_text  \
# ...

# %%
df.sort_values("positive_score")
df.tail(10)
# Out:
#      Unnamed: 0            tweet.created_at      tweet.id  \
# 437          11  2019-09-18 12:34:00.000000  1.174301e+18
# 438          12  2017-12-28 20:28:17.000000  9.464779e+17
# 439          13  2016-05-13 02:54:51.000000  7.309544e+17
# 440          14  2018-02-15 16:30:40.000000  9.641751e+17
# 441          15  2018-12-27 18:20:32.000000  1.078355e+18
# 442          16  2015-07-06 15:04:55.000000  6.180731e+17
# 443          17  2017-10-05 19:53:16.000000  9.160285e+17
# 444          18  2019-06-09 14:27:28.000000  1.137728e+18
# 445          19  2019-01-08 11:09:45.000000  1.082595e+18
# 446          20  2018-06-06 07:15:36.000000  1.004261e+18
#
#                                                                                                                                                                                                                                                                                     tweet_full_text  \
# ...
